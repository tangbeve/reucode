# %%
''''
To be able to run the various scripts,
   this notebook was placed in the San Antonio/ CSV directory.
   This was done to try to avoid any hardcoded path that would not work
   in another computer. 
   
''''
import geopandas as gpd
import pandas as pd
import os

# %%
# To get all the csv files I went to the csv directory and ran the script in bash
# ls | grep .csv | sed -e '$!s/^/"/' -e '$!s/$/",/'
csvfiles = ["AGES65ANDOVER_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"AIRQUALITY_1_2015_2017-12-09T125732_BKJ.csv",
"ALL_MALES_AND_FEMALES_UNDER_5_75_OVER_WITH_HEARING_DIFFICULTY_1_2015_2017-12-01T163342_BKJ.csv",
"ALL_MALES_AND_FEMALES_UNDER_5_75_OVER_WITH_VISION_DIFFICULTY_1_2015_2017-12-01T163342_BKJ.csv",
"ASTHMA_1_2015-01-01_2017-11-30T133824_BKJ.csv",
"COMMGARDENLOCATION_1_2017_2017-12-05T155004_DPOINTG.csv",
"COSTLIVING_1_2015-01-01_2017-11-30T133824_BKJ.csv",
"FARMMARKETLOCATION_1_2015-01-01_2017-11-30T133824_APG.csv",
"FOODPANTRYLOCATION_1_2017_2017-12-05T215756_APG.csv",
"GRANDPARENTS_RESPONSIBLE_FOR_OWN_GRANDCHILDREN_UNDER_18_YEARS_NO_PARENT_PRESENT_1_2015_2017-12-01T163342_BKJ.csv.csv",
"GYMS_1_2015_2017-12-05T124438_DPOINTG.csv",
"HOMELESSSHELTERS_1_2015-01-01_2017-11-30T133824_APG.csv",
"HOSPITALRATINGS_1_2015-01-01_2017-11-30T133824_APOINTG.csv",
"HOURSSPENTOUTHOME_1_2017_2017-12-07T095914_RKJ.csv",
"HOURSSPENTOUTHOME_2_2017_2017-12-07T095914_RKJ.csv",
"LackingProseLiteracy_1_2015-01-01_2017-11-30T133824_SAEBKJ.csv",
"LackOfHealthInsurance_1_2014_2017-12-01T102741_BKJ.csv",
"MENTALHEALTHPROVIDERSACCEPTMEDICADE_1_2017_2017-12-01T163342_DPOINTG.csv",
"PERCAPINCOME_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERCOLLEGESTUDENT_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERFEMALEHEADHH_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERHHLIMITEDENGLISH_1_2015-01-01_2017-11-30T133824_BKJ.csv",
"PERHHMORTGAGE_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERLOWACCESSGROCERY_1_2015_2017-12-05T124438_RKJ.csv",
"PERPOPLIVINGNONFAMHHALONE_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERRENTINCOM_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"PERSCHOOLFREEREDUCEDLUNCH_1_2017_2017-12-04T124715_RKJ.csv",
"PERVACANT_1_2015-01-01_2017-11-30T133824_RKJ.csv",
"POVERTY_STATUS_OF_INDIVIDUALS_IN_PAST_12_MONTHS_BY_LIVING_ARRANGEMENT_1_2011_2017-12-01T163342_BKJ.csv",
"POVERTY_STATUS_OF_INDIVIDUALS_IN_PAST_12_MONTHS_BY_LIVING_ARRANGEMENT_1_2014_2017-12-01T163342_BKJ.csv",
"POVERTY_STATUS_OF_INDIVIDUALS_IN_PAST_12_MONTHS_BY_LIVING_ARRANGEMENT_1_2015_2017-12-01T163342_BKJ.csv",
"POVERTY_STATUS_OF_INDIVIDUALS_IN_PAST_12_MONTHS_BY_LIVING_ARRANGEMENT_CENSUSTRACT_1_2012_2017-12-01T163342_BKJ.csv",
# To get a list of all the shapefiles I did the following script with bash
# ls | grep .shp | sed -e '$!s/^/"/' -e '$!s/$/",/'
# 

shapefiles = ["AIRQUALITY_1_2015_2017-12-09T125732_RKJ",
"COMMGARDENLOCATION_1_2017_2017-12-05T155004_DPOINTG",
"FARMMARKETLOCATION_1_2015-01-01_2017-11-30T133824_APG",
"FOODPANTRYLOCATION_1_2017_2017-12-05T215756_APG",
"GYMS_1_2015_2017-12-05T124438_DPOINTG",
"HOMELESSSHELTERS_1_2015-01-01_2017-11-30T133824_APG",
"HOSPITALRATINGS_1_2015-01-01_2017-11-30T133824_APOINTG",
"MENTALHEALTHPROVIDERSACCEPTMEDICADE_1_2017_2017-12-01T163342_DPOINTG",
"PERSCHOOLFREEREDUCEDLUNCH_1_2017_2017-12-04T124715_RKJ",
"PROXBIKETRAILS_1_2015-01-01_2017-11-30T133824_ALINEJG",
"PROXCOMCENTERS_1_2015-01-01_2017-12-08T133824_DPOINTJG",
"PROXCOMGUIDANCE_1_2015-01-01_2017-11-30T133824_DPOINTJG",
"PROXCOMNUTRITION_1_2015-01-01_2017-12-08T133824_DPOINTJG",
"PROXHIKINGTRAILS_1_2015-01-01_2017-11-30T133824_ALINEJG",
"PROXHOSPITALS_1_2015-01-01_2017-11-30T133824_DPOINTG",
"PROXLIBRARIES_1_2015-01-01_2017-11-30T133824_DPOINTG",
"PROXPARKS_1_2015-01-01_2017-11-30T133824_APOINTJG",
"PROXPHARMACIES_1_2015-01-01_2017-11-30T133824_DPOINTG",
"PROXSIDEWALKS_1_2017_2017-12-01T143720_DLINEG",
"PROXTOPUBLICTRANSIT_1_2015_2017-12-05T084510_DPOINTJG",
"PROXURGENT_1_2015-01-01_2017-11-30T133824_DPOINTG",
"PROXWORSHIPS_1_2017_2017-12-01T163342_DPOINTJG",
"TRAFFICACCIDENTS_1_2017_2017-12-06T115823_RKJ"]


print("CSV Files {}".format(len(csvfiles)))
print("Shapefiles {}".format(len(shapefiles)))

csv_shape_dict = {}

# Some CSV files have a slightly different name than the shapefiles
# Therefore I took only the first 10 characters of the shapefile to match
#   it with the csv file. After I link each shapefile with its respective
#   csv file, I begin to open the shapefiles and the CSV files for comparison.
for s in shapefiles:
    #print(s[:10])
    found = [csvfiles.index(i) for i in csvfiles if s[:10] in i]
    csv_shape_dict[s] = csvfiles[found[0]]
    #print(found)
    
index = 0

# After examining the information in the shapefiles with its CSV
#    it was determined that the shapefile contained the same information
#    of the matched CSV and also contained location information such as
#    the latitude, longitude, and the shape of the location being described. 
while(index < len(shapefiles)):
    shape_df = gpd.GeoDataFrame.from_file("shapefiles/{}.shp".format(shapefiles[index]))
    os.chdir('shpCSV')
    shape_df.to_csv('shape_'+shapefiles[index]+'.csv')
    os.chdir('..')
    index+=1



#shape_df = gpd.GeoDataFrame.from_file(shapefiles[index])
#shape_df = gpd.GeoDataFrame.from_file("shapefiles/{}.shp".format(shapefiles[index]))
#csv_file_path = "{}.csv".format(shapefiles[2])
#csv_df = pd.read_csv(csv_shape_dict[shapefiles[index]])
# Out:
# CSV Files 75
# Shapefiles 23
